# %%
# ==============================================================================
# 0. KAGGLE ENVIRONMENT SETUP: INSTALL LIBRARIES
# ==============================================================================
# !pip install torchxrayvision -q

# ==============================================================================
# 1. IMPORTS AND SETUP
# ==============================================================================
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW

import pandas as pd
import numpy as np
import cv2
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (roc_auc_score, roc_curve, classification_report,
                             confusion_matrix, precision_recall_curve, average_precision_score)
from tqdm import tqdm
import os
import glob
import timm

# The library for pre-trained x-ray models
import torchxrayvision as xrv

from einops import rearrange
from einops.layers.torch import Rearrange
import albumentations as A
from albumentations.pytorch import ToTensorV2

sns.set_style("whitegrid")

# ==============================================================================
# 2. DATA HANDLING AND VISUALIZATION
# ==============================================================================

def show_image_grid(df, labels, n_images=25, random_state=42):
    plt.figure(figsize=(15, 15)); sample_df = df.sample(n_images, random_state=random_state)
    for i, (idx, row) in enumerate(sample_df.iterrows()):
        plt.subplot(5, 5, i + 1); image_path = row['FullPath']; image = cv2.imread(image_path)
        if image is None: continue
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image_labels = [label for label in labels if row[label] == 1]
        title = "\n".join(image_labels) if image_labels else "No Finding"
        plt.imshow(image); plt.title(title, fontsize=8); plt.axis('off')
    plt.tight_layout(); plt.show()

class NIHChestXrayDataset(Dataset):
    def __init__(self, df, labels, transform=None, is_val=False):
        self.df, self.transform, self.labels, self.is_val = df, transform, labels, is_val
    def __len__(self): return len(self.df)
    def __getitem__(self, idx):
        row = self.df.iloc[idx]; image_path = row['FullPath']
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE); image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        original_image = cv2.resize(image, (CONFIG['IMAGE_SIZE'], CONFIG['IMAGE_SIZE']))
        if self.transform: image = self.transform(image=image)['image']
        labels_vector = torch.tensor(row[self.labels].values.astype(np.float32))
        return (image, labels_vector, original_image) if self.is_val else (image, labels_vector)

def get_transforms(image_size):
    """
    Defines augmentations that scale the image to the [0, 1] float range,
    matching the torchxrayvision model's expectation.
    """
    train_transform = A.Compose([
        A.Resize(image_size, image_size),
        A.HorizontalFlip(p=0.5), A.Rotate(limit=15, p=0.7),
        A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.7),
        A.ToFloat(max_value=255.0), # Scale to [0, 1]
        ToTensorV2()
    ])
    val_transform = A.Compose([
        A.Resize(image_size, image_size),
        A.ToFloat(max_value=255.0), # Scale to [0, 1]
        ToTensorV2()
    ])
    return train_transform, val_transform

# ==============================================================================
# 3. MODEL ARCHITECTURE: SemaCheX-Former (with NIH Backbone)
# ==============================================================================

class TransformerEncoderBlock(nn.Module):
    def __init__(self, dim, num_heads, mlp_dim, dropout=0.1):
        super().__init__(); self.norm1, self.attn, self.norm2 = nn.LayerNorm(dim), nn.MultiheadAttention(dim, num_heads, dropout=dropout, batch_first=True), nn.LayerNorm(dim)
        self.mlp = nn.Sequential(nn.Linear(dim, mlp_dim), nn.GELU(), nn.Dropout(dropout), nn.Linear(mlp_dim, dim), nn.Dropout(dropout))
    def forward(self, x):
        normed_x = self.norm1(x); x = x + self.attn(normed_x, normed_x, normed_x)[0]; x = x + self.mlp(self.norm2(x)); return x

class PartitionReconstructionAttentionBlock_LMSA(nn.Module):
    def __init__(self, in_channels, dim, patch_size, num_heads, mlp_dim, num_classes, dropout=0.1):
        super().__init__(); self.patch_size, patch_dim = patch_size, in_channels * (patch_size ** 2)
        self.partition = Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=patch_size, p2=patch_size)
        self.patch_projection = nn.Linear(patch_dim, dim); self.label_embeddings = nn.Parameter(torch.randn(1, num_classes, dim))
        self.attention_module = TransformerEncoderBlock(dim, num_heads, mlp_dim, dropout)
    def forward(self, x):
        b, _, h, w = x.shape; tokens, label_embs = self.partition(x), self.label_embeddings.expand(b, -1, -1)
        tokens = self.patch_projection(tokens); processed_tokens = self.attention_module(torch.cat((tokens, label_embs), dim=1))
        processed_visual_tokens = processed_tokens[:, :tokens.shape[1]]; recon_h, recon_w = h // self.patch_size, w // self.patch_size
        return rearrange(processed_visual_tokens, 'b (h w) d -> b d h w', h=recon_h, w=recon_w)

class ConvSEBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, reduction=8):
        super().__init__()
        self.conv_block = nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size, padding='same', bias=False), nn.BatchNorm2d(out_channels), nn.ReLU(inplace=True))
        self.se = nn.Sequential(nn.AdaptiveAvgPool2d(1), nn.Conv2d(out_channels, out_channels // reduction, 1, bias=False), nn.ReLU(inplace=True), nn.Conv2d(out_channels // reduction, out_channels, 1, bias=False), nn.Sigmoid())
    def forward(self, x): cnn_out = self.conv_block(x); return cnn_out * self.se(cnn_out)

class SemaCheXFormer(nn.Module):
    def __init__(self, num_classes=14, dim=256, num_heads=8, mlp_dim=512, cnn_channels=256):
        super().__init__()
        pretrained_model = xrv.models.DenseNet(weights="densenet121-res224-nih")
        self.backbone = pretrained_model.features
        self.backbone.conv0 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.backbone.norm0 = nn.BatchNorm2d(64)
        backbone_out_channels = 1024
        self.attention_stage = PartitionReconstructionAttentionBlock_LMSA(backbone_out_channels, dim, 1, num_heads, mlp_dim, num_classes)
        self.cnn_se_stage = ConvSEBlock(dim, cnn_channels)
        self.classification_head = nn.Sequential(nn.AdaptiveAvgPool2d(1), nn.Flatten(), nn.Dropout(p=0.2, inplace=True), nn.Linear(cnn_channels, num_classes))

    def forward(self, x):
        features = self.backbone(x)
        attention_out = self.attention_stage(features)
        cnn_out = self.cnn_se_stage(attention_out)
        return self.classification_head(cnn_out)

# ==============================================================================
# 4. CHECKPOINT MANAGEMENT
# ==============================================================================

def save_checkpoint(epoch, model, optimizer, scheduler, scaler, history, best_val_loss, filepath='checkpoint.pth'):
    """Save complete training state"""
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict(),
        'scaler_state_dict': scaler.state_dict(),
        'history': history,
        'best_val_loss': best_val_loss
    }
    torch.save(checkpoint, filepath)
    print(f"💾 Checkpoint saved at epoch {epoch+1} → {filepath}")

def load_checkpoint(filepath, model, optimizer, scheduler, scaler):
    """Load training state from checkpoint"""
    if not os.path.exists(filepath):
        print(f"⚠️  No checkpoint found at {filepath}. Starting from scratch.")
        return 0, {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}, float('inf')
    
    print(f"📂 Loading checkpoint from {filepath}...")
    checkpoint = torch.load(filepath, map_location='cpu')  # Load to CPU first
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    scaler.load_state_dict(checkpoint['scaler_state_dict'])
    
    start_epoch = checkpoint['epoch'] + 1
    history = checkpoint['history']
    best_val_loss = checkpoint['best_val_loss']
    
    print(f"✅ Resumed from epoch {start_epoch} | Best Val Loss: {best_val_loss:.4f}")
    return start_epoch, history, best_val_loss

def find_checkpoint(possible_paths):
    """Find the first existing checkpoint from a list of paths"""
    for path in possible_paths:
        if os.path.exists(path):
            print(f"🔄 Found checkpoint: {path}")
            return path
    print("⚠️  No checkpoint found in any of the specified paths.")
    return None

def load_model_weights_only(filepath, model):
    """Load only model weights (from best_model.pth) and start fresh optimizer/scheduler"""
    if not os.path.exists(filepath):
        print(f"⚠️  No model weights found at {filepath}.")
        return False
    
    print(f"📂 Loading model weights from {filepath}...")
    model.load_state_dict(torch.load(filepath, map_location='cpu'))
    print(f"✅ Model weights loaded successfully! Starting training with fresh optimizer.")
    return True

# ==============================================================================
# 5. TRAINING AND EVALUATION LOOPS
# ==============================================================================
def train_one_epoch(model, dataloader, criterion, optimizer, device, scaler):
    model.train(); total_loss, all_preds, all_labels = 0, [], []
    for images, labels in tqdm(dataloader, desc="Training"):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad(set_to_none=True)
        with torch.cuda.amp.autocast(): outputs = model(images); loss = criterion(outputs, labels)
        scaler.scale(loss).backward(); scaler.step(optimizer); scaler.update()
        total_loss += loss.item(); all_preds.append(torch.sigmoid(outputs).detach().cpu().numpy()); all_labels.append(labels.cpu().numpy())
    avg_loss, all_preds, all_labels = total_loss/len(dataloader), np.vstack(all_preds), np.vstack(all_labels)
    accuracy = ((all_preds > 0.5).astype(int) == all_labels).mean()
    return avg_loss, accuracy

def evaluate(model, dataloader, criterion, device):
    model.eval(); total_loss, all_preds, all_labels, all_original_images = 0, [], [], []
    with torch.no_grad():
        for images, labels, original_images in tqdm(dataloader, desc="Validating"):
            images, labels = images.to(device), labels.to(device)
            with torch.cuda.amp.autocast(): outputs = model(images); loss = criterion(outputs, labels)
            total_loss += loss.item(); all_preds.append(torch.sigmoid(outputs).cpu().numpy()); all_labels.append(labels.cpu().numpy()); all_original_images.append(original_images.numpy())
    avg_loss, all_preds, all_labels, all_original_images = total_loss/len(dataloader), np.vstack(all_preds), np.vstack(all_labels), np.vstack(all_original_images)
    accuracy = ((all_preds > 0.5).astype(int) == all_labels).mean()
    return avg_loss, accuracy, all_preds, all_labels, all_original_images

# ==============================================================================
# 6. PLOTTING AND METRICS REPORTING
# ==============================================================================
def plot_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6)); ax1.plot(history['train_loss'], 'o--', label='Train Loss'); ax1.plot(history['val_loss'], 'o-', label='Validation Loss')
    ax1.set_title('Model Loss'); ax1.set_xlabel('Epochs'); ax1.legend(); ax2.plot(history['train_acc'], 'o--', label='Train Accuracy'); ax2.plot(history['val_acc'], 'o-', label='Validation Accuracy')
    ax2.set_title('Model Accuracy'); ax2.set_xlabel('Epochs'); ax2.legend(); plt.show()

def plot_roc_curves(y_true, y_pred, labels):
    plt.figure(figsize=(12, 10))
    for i, label in enumerate(labels):
        if len(np.unique(y_true[:, i]))<2: continue
        fpr,tpr,_=roc_curve(y_true[:,i],y_pred[:,i]); plt.plot(fpr,tpr,label=f'{label} (AUC={roc_auc_score(y_true[:,i],y_pred[:,i]):.3f})')
    plt.plot([0,1],[0,1],'k--',label='Chance'); plt.title('ROC Curves'); plt.xlabel('FPR'); plt.ylabel('TPR'); plt.legend(loc='lower right'); plt.show()

def plot_precision_recall_curves(y_true, y_pred, labels):
    plt.figure(figsize=(12, 10))
    for i, label in enumerate(labels):
        if len(np.unique(y_true[:, i]))<2: continue
        prec,rec,_=precision_recall_curve(y_true[:,i],y_pred[:,i]); plt.plot(rec,prec,label=f'{label} (AP={average_precision_score(y_true[:,i],y_pred[:,i]):.3f})')
    plt.title('Precision-Recall Curves'); plt.xlabel('Recall'); plt.ylabel('Precision'); plt.legend(loc='upper right'); plt.show()

def plot_confusion_matrices(y_true, y_pred, labels):
    y_pred_binary=(y_pred>0.5).astype(int); n_labels,n_cols=len(labels),4; n_rows=n_labels//n_cols+(1 if n_labels%n_cols else 0)
    fig,axes=plt.subplots(n_rows,n_cols,figsize=(20,5*n_rows)); axes=axes.flatten()
    for i,label in enumerate(labels):
        cm=confusion_matrix(y_true[:,i],y_pred_binary[:,i]); sns.heatmap(cm,annot=True,fmt='d',ax=axes[i],cmap='Blues')
        axes[i].set_title(label); axes[i].set_xlabel('Predicted'); axes[i].set_ylabel('True')
    for j in range(i+1,len(axes)): fig.delaxes(axes[j])
    plt.tight_layout(); plt.show()

def print_and_plot_metrics(y_true, y_pred, labels):
    y_pred_binary=(y_pred>0.5).astype(int); print("Classification Report\n"+"="*70); print(classification_report(y_true,y_pred_binary,target_names=labels,zero_division=0))
    auc_scores=[roc_auc_score(y_true[:,i],y_pred[:,i]) if len(np.unique(y_true[:,i]))>1 else np.nan for i in range(len(labels))]; mean_auc=np.nanmean(auc_scores)
    print("\nROC AUC Scores\n"+"="*70)
    for i,label in enumerate(labels): print(f"{label:<20}: {auc_scores[i]:.4f}" if not np.isnan(auc_scores[i]) else f"{label:<20}: Not Defined")
    print(f"\n{'MEAN AUC':<20}: {mean_auc:.4f}\n")
    report_df=pd.DataFrame(classification_report(y_true,y_pred_binary,target_names=labels,output_dict=True,zero_division=0)).iloc[:-1,:].T
    plt.figure(figsize=(10,8)); sns.heatmap(report_df,annot=True,cmap='viridis',fmt='.2f'); plt.title('Metrics Heatmap'); plt.show()

# ==============================================================================
# 7. MAIN EXECUTION SCRIPT
# ==============================================================================
if __name__ == '__main__':
    
    training_successful = False
    
    try:
        CONFIG = {
            "IMAGE_SIZE": 224, 
            "BATCH_SIZE": 24, 
            "LEARNING_RATE": 0.001,
            "EPOCHS": 30,
            "START_EPOCH": 10,  # ⭐ Set this to the epoch your best_model.pth was saved at
            "DEVICE": "cuda" if torch.cuda.is_available() else "cpu",
            "DATASET_DIR": "/kaggle/input/data",
            "CSV_PATH": "/kaggle/input/data/Data_Entry_2017.csv",
            "CHECKPOINT_PATH": "checkpoint_latest.pth",  # Saved in working directory
            "BEST_MODEL_PATH": "best_model.pth",  # Best model weights only
            "PRETRAINED_WEIGHTS": "/kaggle/input/bestmodel/pytorch/default/1/best_model.pth"  # ⭐ Your pre-trained weights
        }
        
        # ⭐ DEFINE POSSIBLE CHECKPOINT LOCATIONS ⭐
        # The code will check these paths in order and load the first one found
        CHECKPOINT_SEARCH_PATHS = [
            "/kaggle/input/bestmodel/pytorch/default/1/checkpoint_latest.pth",  # From previous run (Kaggle input)
            "/kaggle/input/bestmodel/checkpoint_latest.pth",  # Alternative path
            "checkpoint_latest.pth",  # Current working directory
        ]

        print(f"--- Training SemaCheXFormer with NIH Pre-trained Backbone | Device: {CONFIG['DEVICE']} ---")
        
        try: df = pd.read_csv(CONFIG['CSV_PATH'])
        except FileNotFoundError:
            print("="*80 + "\nFATAL ERROR: Could not find CSV. Please update 'CSV_PATH' and 'DATASET_DIR' in CONFIG.\n" + "="*80); raise

        all_image_paths = {os.path.basename(x): x for x in glob.glob(os.path.join(CONFIG['DATASET_DIR'], 'images*', '*', '*.png'))}
        if not all_image_paths: raise FileNotFoundError("FATAL ERROR: No images found.")

        df['FullPath'] = df['Image Index'].map(all_image_paths.get); df.dropna(subset=['FullPath'], inplace=True)
        all_labels_str = df['Finding Labels'].str.get_dummies(sep='|'); LABELS = [l for l in all_labels_str.columns if l != 'No Finding']
        df = pd.concat([df, all_labels_str[LABELS]], axis=1)
        print(f"Successfully processed {len(df)} images.")
        
        train_df, val_df = df.sample(frac=0.8, random_state=42), df.drop(df.sample(frac=0.8, random_state=42).index)
        print(f"Training size: {len(train_df)} | Validation size: {len(val_df)}")

        train_transform, val_transform = get_transforms(CONFIG["IMAGE_SIZE"])
        train_dataset = NIHChestXrayDataset(train_df, LABELS, transform=train_transform)
        val_dataset = NIHChestXrayDataset(val_df, LABELS, transform=val_transform, is_val=True)
        train_loader = DataLoader(train_dataset, batch_size=CONFIG['BATCH_SIZE'], shuffle=True, num_workers=2, pin_memory=True)
        val_loader = DataLoader(val_dataset, batch_size=CONFIG['BATCH_SIZE'], shuffle=False, num_workers=2, pin_memory=True)

        model = SemaCheXFormer(num_classes=len(LABELS)).to(CONFIG['DEVICE'])
        
        pos_counts = train_df[LABELS].sum(); pos_weights = (len(train_df) - pos_counts) / pos_counts
        criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weights.values, dtype=torch.float32).to(CONFIG['DEVICE']))
        optimizer = AdamW([
            {'params': model.backbone.parameters(), 'lr': CONFIG['LEARNING_RATE'] / 10},
            {'params': model.attention_stage.parameters(), 'lr': CONFIG['LEARNING_RATE']},
            {'params': model.cnn_se_stage.parameters(), 'lr': CONFIG['LEARNING_RATE']},
            {'params': model.classification_head.parameters(), 'lr': CONFIG['LEARNING_RATE']}])
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True)
        scaler = torch.cuda.amp.GradScaler()

        # ⭐ SEARCH FOR AND LOAD CHECKPOINT ⭐
        # Priority 1: Try to load full checkpoint (has optimizer, scheduler, history)
        checkpoint_path = find_checkpoint(CHECKPOINT_SEARCH_PATHS)
        
        if checkpoint_path:
            # Full checkpoint found - resume everything
            start_epoch, history, best_val_loss = load_checkpoint(
                checkpoint_path, model, optimizer, scheduler, scaler
            )
        elif os.path.exists(CONFIG['PRETRAINED_WEIGHTS']):
            # Only model weights found - load them and start fresh
            print(f"\n{'='*70}")
            print(f"🔄 No full checkpoint found, but found pre-trained weights!")
            print(f"📂 Loading: {CONFIG['PRETRAINED_WEIGHTS']}")
            print(f"{'='*70}\n")
            
            if load_model_weights_only(CONFIG['PRETRAINED_WEIGHTS'], model):
                start_epoch = CONFIG['START_EPOCH']  # Start from epoch 11 (you completed 10)
                history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
                best_val_loss = float('inf')  # Reset best loss tracking
                print(f"✅ Will continue training from epoch {start_epoch + 1} to {CONFIG['EPOCHS']}")
                print(f"⚠️  Note: Optimizer and scheduler are initialized fresh (not resumed)")
            else:
                start_epoch = 0
                history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
                best_val_loss = float('inf')
        else:
            # Nothing found - start from scratch
            start_epoch = 0
            history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
            best_val_loss = float('inf')
            print("⚠️  No checkpoint or pre-trained weights found. Starting training from scratch.")

        print(f"--- Starting training from epoch {start_epoch+1} to {CONFIG['EPOCHS']} with AMP ---")
        
        for epoch in range(start_epoch, CONFIG['EPOCHS']):
            print(f"\n--- Epoch {epoch+1}/{CONFIG['EPOCHS']} ---")
            train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, CONFIG['DEVICE'], scaler)
            val_loss, val_acc, y_pred, y_true, val_images = evaluate(model, val_loader, criterion, CONFIG['DEVICE'])
            
            history['train_loss'].append(train_loss); history['val_loss'].append(val_loss)
            history['train_acc'].append(train_acc); history['val_acc'].append(val_acc)
            print(f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
            
            # ⭐ SAVE BEST MODEL SEPARATELY ⭐
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                torch.save(model.state_dict(), CONFIG['BEST_MODEL_PATH'])
                print(f"🏆 Best model saved with val_loss: {best_val_loss:.4f}")
            
            # ⭐ SAVE CHECKPOINT EVERY EPOCH ⭐
            save_checkpoint(epoch, model, optimizer, scheduler, scaler, history, best_val_loss, CONFIG['CHECKPOINT_PATH'])
            
            scheduler.step(val_loss)

        torch.save(model.state_dict(), f'final_model_{CONFIG["EPOCHS"]}_epochs.pth')
        training_successful = True

    finally:
        if training_successful:
            print("\n\n--- 📈 Final Evaluation & Visualization ---")
            model_path = CONFIG['BEST_MODEL_PATH']
            if not os.path.exists(model_path): 
                model_path = f'final_model_{CONFIG["EPOCHS"]}_epochs.pth'
            
            if os.path.exists(model_path):
                model = SemaCheXFormer(num_classes=len(LABELS)).to(CONFIG['DEVICE'])
                model.load_state_dict(torch.load(model_path))
                print(f"--- Loaded model from {model_path} for evaluation. ---")
                
                _, _, y_pred, y_true, _ = evaluate(model, val_loader, criterion, CONFIG['DEVICE'])
                
                plot_history(history)
                plot_roc_curves(y_true, y_pred, LABELS)
                plot_precision_recall_curves(y_true, y_pred, LABELS)
                plot_confusion_matrices(y_true, y_pred, LABELS)
                print_and_plot_metrics(y_true, y_pred, LABELS)
            else:
                print("No models were saved. Cannot run final evaluation.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 86.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 55.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# --- Training SemaCheXFormer with NIH Pre-trained Backbone | Device: cuda ---
# Successfully processed 112120 images.
# Training size: 89696 | Validation size: 22424
# Downloading weights...
# If this fails you can run `wget https://github.com/mlmed/torchxrayvision/releases/download/v1/nih-densenet121-d121-tw-lr001-rot45-tr15-sc15-seed0-best.pt -O /root/.torchxrayvision/models_data/nih-densenet121-d121-tw-lr001-rot45-tr15-sc15-seed0-best.pt`
# [██████████████████████████████████████████████████]
# ⚠️  No checkpoint found in any of the specified paths.
#
# ======================================================================
# 🔄 No full checkpoint found, but found pre-trained weights!
# 📂 Loading: /kaggle/input/bestmodel/pytorch/default/1/best_model.pth
# ======================================================================
#
# 📂 Loading model weights from /kaggle/input/bestmodel/pytorch/default/1/best_model.pth...
# ✅ Model weights loaded successfully! Starting training with fresh optimizer.
# ✅ Will continue training from epoch 11 to 30
# ⚠️  Note: Optimizer and scheduler are initialized fresh (not resumed)
# --- Starting training from epoch 11 to 30 with AMP ---
#
# --- Epoch 11/30 ---
# Training:  49%|████▉     | 1834/3738 [11:22<14:13,  2.23it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [23:14<00:00,  2.68it/s]
# Validating:  10%|▉         | 91/935 [00:30<04:38,  3.03it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [06:05<00:00,  2.56it/s]
# Epoch 11 | Train Loss: 1.0247 | Val Loss: 1.0322 | Val Acc: 0.6914
# 🏆 Best model saved with val_loss: 1.0322
# 💾 Checkpoint saved at epoch 11 → checkpoint_latest.pth
#
# --- Epoch 12/30 ---
# Training:  41%|████      | 1533/3738 [12:06<19:31,  1.88it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [26:51<00:00,  2.32it/s]
# Validating:  10%|█         | 94/935 [00:31<04:09,  3.37it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:49<00:00,  3.23it/s]
# Epoch 12 | Train Loss: 1.0175 | Val Loss: 1.0186 | Val Acc: 0.7263
# 🏆 Best model saved with val_loss: 1.0186
# 💾 Checkpoint saved at epoch 12 → checkpoint_latest.pth
#
# --- Epoch 13/30 ---
# Training:  67%|██████▋   | 2500/3738 [14:34<05:47,  3.56it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [22:50<00:00,  2.73it/s]
# Validating:  10%|█         | 94/935 [00:28<03:49,  3.66it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [05:09<00:00,  3.02it/s]
# Epoch 13 | Train Loss: 1.0051 | Val Loss: 1.0180 | Val Acc: 0.7036
# 🏆 Best model saved with val_loss: 1.0180
# 💾 Checkpoint saved at epoch 13 → checkpoint_latest.pth
#
# --- Epoch 14/30 ---
# Training:  65%|██████▍   | 2420/3738 [14:12<09:33,  2.30it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [22:07<00:00,  2.82it/s]
# Validating:  10%|█         | 94/935 [00:36<04:06,  3.41it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [05:02<00:00,  3.09it/s]
# Epoch 14 | Train Loss: 1.0100 | Val Loss: 1.0102 | Val Acc: 0.6919
# 🏆 Best model saved with val_loss: 1.0102
# 💾 Checkpoint saved at epoch 14 → checkpoint_latest.pth
#
# --- Epoch 15/30 ---
# Training:  84%|████████▎ | 3122/3738 [19:47<05:15,  1.95it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [23:45<00:00,  2.62it/s]
# Validating:  10%|█         | 94/935 [00:37<04:30,  3.11it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [05:10<00:00,  3.01it/s]
# Epoch 15 | Train Loss: 0.9928 | Val Loss: 1.0302 | Val Acc: 0.7080
# 💾 Checkpoint saved at epoch 15 → checkpoint_latest.pth
#
# --- Epoch 16/30 ---
# Training:  20%|█▉        | 732/3738 [04:14<16:35,  3.02it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [23:14<00:00,  2.68it/s]
# Validating:  10%|▉         | 93/935 [00:34<05:08,  2.73it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:48<00:00,  3.24it/s]
# Epoch 16 | Train Loss: 0.9930 | Val Loss: 1.0388 | Val Acc: 0.6983
# 💾 Checkpoint saved at epoch 16 → checkpoint_latest.pth
#
# --- Epoch 17/30 ---
# Training:  99%|█████████▉| 3694/3738 [20:42<00:12,  3.48it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [20:56<00:00,  2.98it/s]
# Validating:  10%|█         | 94/935 [00:28<04:16,  3.28it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:58<00:00,  3.13it/s]
# Epoch 17 | Train Loss: 0.9857 | Val Loss: 1.0477 | Val Acc: 0.7239
# 💾 Checkpoint saved at epoch 17 → checkpoint_latest.pth
#
# --- Epoch 18/30 ---
# Training:  64%|██████▎   | 2382/3738 [13:03<06:58,  3.24it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [20:49<00:00,  2.99it/s]
# Validating:  10%|█         | 94/935 [00:30<04:13,  3.32it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:50<00:00,  3.22it/s]
# Epoch 18 | Train Loss: 0.9715 | Val Loss: 1.0193 | Val Acc: 0.7375
# 💾 Checkpoint saved at epoch 18 → checkpoint_latest.pth
#
# --- Epoch 19/30 ---
# Training:  53%|█████▎    | 1976/3738 [10:43<10:17,  2.85it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [21:10<00:00,  2.94it/s]
# Validating:  10%|█         | 94/935 [00:29<03:46,  3.71it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:54<00:00,  3.18it/s]
# Epoch 19 | Train Loss: 0.9494 | Val Loss: 1.0203 | Val Acc: 0.7382
# 💾 Checkpoint saved at epoch 19 → checkpoint_latest.pth
#
# --- Epoch 20/30 ---
# Training:  84%|████████▍ | 3147/3738 [17:19<02:52,  3.43it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [20:41<00:00,  3.01it/s]
# Validating:  10%|█         | 94/935 [00:29<04:51,  2.89it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:51<00:00,  3.21it/s]
# Epoch 20 | Train Loss: 0.9497 | Val Loss: 1.0140 | Val Acc: 0.7404
# 💾 Checkpoint saved at epoch 20 → checkpoint_latest.pth
#
# --- Epoch 21/30 ---
# Training:  66%|██████▌   | 2462/3738 [13:44<08:53,  2.39it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [21:34<00:00,  2.89it/s]
# Validating:  10%|█         | 95/935 [00:35<05:18,  2.64it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [05:08<00:00,  3.03it/s]
# Epoch 21 | Train Loss: 0.9453 | Val Loss: 1.0164 | Val Acc: 0.7308
# 💾 Checkpoint saved at epoch 21 → checkpoint_latest.pth
#
# --- Epoch 22/30 ---
# Training:   1%|▏         | 54/3738 [00:18<19:47,  3.10it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [22:21<00:00,  2.79it/s]
# Validating:  10%|█         | 94/935 [00:50<08:07,  1.72it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [05:41<00:00,  2.74it/s]
# Epoch 22 | Train Loss: 0.9429 | Val Loss: 1.0140 | Val Acc: 0.7503
# 💾 Checkpoint saved at epoch 22 → checkpoint_latest.pth
#
# --- Epoch 23/30 ---
# Training:   5%|▍         | 177/3738 [01:03<19:33,  3.03it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [22:03<00:00,  2.82it/s]
# Validating:  10%|█         | 94/935 [00:28<05:43,  2.45it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:39<00:00,  3.34it/s]
# Epoch 23 | Train Loss: 0.9421 | Val Loss: 1.0156 | Val Acc: 0.7353
# 💾 Checkpoint saved at epoch 23 → checkpoint_latest.pth
#
# --- Epoch 24/30 ---
# Training:  33%|███▎      | 1242/3738 [06:39<12:08,  3.42it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [20:23<00:00,  3.05it/s]
# Validating:  10%|▉         | 91/935 [00:29<04:21,  3.22it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [05:06<00:00,  3.05it/s]
# Epoch 24 | Train Loss: 0.9422 | Val Loss: 1.0213 | Val Acc: 0.7477
# 💾 Checkpoint saved at epoch 24 → checkpoint_latest.pth
#
# --- Epoch 25/30 ---
# Training:  14%|█▎        | 506/3738 [02:43<18:04,  2.98it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [21:27<00:00,  2.90it/s]
# Validating:  10%|▉         | 91/935 [00:37<06:42,  2.10it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [05:24<00:00,  2.88it/s]
# Epoch 25 | Train Loss: 0.9414 | Val Loss: 1.0157 | Val Acc: 0.7472
# 💾 Checkpoint saved at epoch 25 → checkpoint_latest.pth
#
# --- Epoch 26/30 ---
# Training:  96%|█████████▋| 3599/3738 [19:40<00:58,  2.39it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [20:51<00:00,  2.99it/s]
# Validating:  10%|█         | 94/935 [00:48<06:50,  2.05it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [06:37<00:00,  2.35it/s]
# Epoch 26 | Train Loss: 0.9414 | Val Loss: 1.0156 | Val Acc: 0.7524
# 💾 Checkpoint saved at epoch 26 → checkpoint_latest.pth
#
# --- Epoch 27/30 ---
# Training:   4%|▍         | 157/3738 [01:06<22:40,  2.63it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [24:52<00:00,  2.50it/s]
# Validating:  10%|█         | 94/935 [00:29<03:53,  3.60it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:54<00:00,  3.17it/s]
# Epoch 27 | Train Loss: 0.9442 | Val Loss: 1.0142 | Val Acc: 0.7335
# 💾 Checkpoint saved at epoch 27 → checkpoint_latest.pth
#
# --- Epoch 28/30 ---
# Training:  12%|█▏        | 454/3738 [02:25<16:14,  3.37it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [20:30<00:00,  3.04it/s]
# Validating:  10%|▉         | 93/935 [00:30<04:19,  3.25it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:54<00:00,  3.17it/s]
# Epoch 28 | Train Loss: 0.9417 | Val Loss: 1.0205 | Val Acc: 0.7427
# 💾 Checkpoint saved at epoch 28 → checkpoint_latest.pth
#
# --- Epoch 29/30 ---
# Training:  16%|█▌        | 594/3738 [03:47<18:01,  2.91it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [24:44<00:00,  2.52it/s]
# Validating:  10%|▉         | 91/935 [00:31<04:48,  2.92it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [06:03<00:00,  2.57it/s]
# Epoch 29 | Train Loss: 0.9432 | Val Loss: 1.0153 | Val Acc: 0.7372
# 💾 Checkpoint saved at epoch 29 → checkpoint_latest.pth
#
# --- Epoch 30/30 ---
# Training:  87%|████████▋ | 3242/3738 [25:19<03:14,  2.55it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Training: 100%|██████████| 3738/3738 [28:25<00:00,  2.19it/s]
# Validating:  10%|█         | 94/935 [00:33<06:02,  2.32it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [06:42<00:00,  2.32it/s]
# Epoch 30 | Train Loss: 0.9420 | Val Loss: 1.0117 | Val Acc: 0.7382
# 💾 Checkpoint saved at epoch 30 → checkpoint_latest.pth
#
#
# --- 📈 Final Evaluation & Visualization ---
# --- Loaded model from best_model.pth for evaluation. ---
# Validating:  10%|█         | 94/935 [00:33<04:51,  2.88it/s]libpng warning: iCCP: profile 'ICC Profile': 'GRAY': Gray color space not permitted on RGB PNG
# Validating: 100%|██████████| 935/935 [04:41<00:00,  3.32it/s]
# Classification Report
# ======================================================================
#                     precision    recall  f1-score   support
#
#        Atelectasis       0.20      0.76      0.31      2346
#       Cardiomegaly       0.09      0.82      0.16       527
#      Consolidation       0.09      0.80      0.16       954
#              Edema       0.07      0.86      0.12       479
#           Effusion       0.25      0.90      0.39      2585
#          Emphysema       0.06      0.81      0.11       515
#           Fibrosis       0.03      0.72      0.05       303
#             Hernia       0.01      0.76      0.02        38
#       Infiltration       0.30      0.56      0.39      3983
#               Mass       0.13      0.76      0.22      1188
#             Nodule       0.09      0.68      0.15      1228
# Pleural_Thickening       0.07      0.73      0.12       687
#          Pneumonia       0.02      0.73      0.04       304
#       Pneumothorax       0.12      0.75      0.21      1037
#
#          micro avg       0.11      0.73      0.20     16174
#          macro avg       0.11      0.76      0.18     16174
#       weighted avg       0.18      0.73      0.27     16174
#        samples avg       0.08      0.32      0.12     16174
#
#
# ROC AUC Scores
# ======================================================================
# Atelectasis         : 0.7660
# Cardiomegaly        : 0.9041
# Consolidation       : 0.7818
# Edema               : 0.8772
# Effusion            : 0.8553
# Emphysema           : 0.8331
# Fibrosis            : 0.7561
# Hernia              : 0.8913
# Infiltration        : 0.6821
# Mass                : 0.8062
# Nodule              : 0.6873
# Pleural_Thickening  : 0.7681
# Pneumonia           : 0.7206
# Pneumothorax        : 0.8186
#
# MEAN AUC            : 0.7963
